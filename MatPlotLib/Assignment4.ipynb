# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../assets/feb-20-us-flight-delay.csv")

# %%
plt.figure()
plt.title("Average flight delays")
plt.xlabel('Day of month')
plt.ylabel('Average delay (hours)')

x = []
for i in range(1, 30):
    x.append(i)
y = df.groupby('DAY_OF_MONTH').mean()['DEP_DEL15']
plt.bar(x, y)
# Out:
# <BarContainer object of 29 artists>
